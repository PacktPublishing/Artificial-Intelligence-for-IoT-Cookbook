# %% [markdown]
# # Upload all pictures from a folder to the cloud
#
# ## prerequisites and configure cloud access credentials

# %%
from azure.cognitiveservices.vision.customvision.training import CustomVisionTrainingClient
from azure.cognitiveservices.vision.customvision.training.models import ImageFileCreateEntry

from pathlib import Path

ENDPOINT = "https://westus2.api.cognitive.microsoft.com"

# Replace with a valid key
training_key = "aa9afbe3879c45d7aa2326c58867187d"

trainer = CustomVisionTrainingClient(training_key, endpoint=ENDPOINT)

projectid="081e259d-c82a-4a49-acc6-27fc1adf8539"

# %% [markdown]
# ## find all images and upload

# %%
base_image_url = "folder1/"

print("Adding images...")

image_list = []

pathlist = Path(base_image_url).glob('*.jpg')
    
x = 0
    
for path in pathlist:
    x= x+ 1
    file_name=str(path)
    print(file_name)
    if x < 59:
        with open(str(path),"rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read()))
    else:
        x = 0
        image_list = []

        upload_result = trainer.create_images_from_files(projectid, images=image_list)
        if not upload_result.is_batch_successful:
            print("Image batch upload failed.")
            exit(-1)

        for image in upload_result.images:
            print("Image status: ", image.status)
    
        print ("starting upload")

    
print("uploaded images")
# Out:
# Adding images...
# folder1/image_1571952654.jpg
# folder1/image_1571952647.jpg
# folder1/image_1571952518.jpg
# folder1/image_1571952679.jpg
# folder1/image_1571952965.jpg
# folder1/image_1571952657.jpg
# folder1/image_1571952661.jpg
# folder1/image_1571952997.jpg
# folder1/image_1571953247.jpg
# folder1/image_1571952587.jpg
# folder1/image_1571952993.jpg
# folder1/image_1571952525.jpg
# folder1/image_1571952707.jpg
# folder1/image_1571953258.jpg
# folder1/image_1571952697.jpg
# folder1/image_1571953240.jpg
# folder1/image_1571952986.jpg
# folder1/image_1571952550.jpg
# folder1/image_1571952535.jpg
# folder1/image_1571953374.jpg
# folder1/image_1571953419.jpg
# folder1/image_1571952676.jpg
# folder1/image_1571953408.jpg
# folder1/image_1571952733.jpg
# folder1/image_1571953268.jpg
# folder1/image_1571953388.jpg
# folder1/image_1571953356.jpg
# folder1/image_1571952979.jpg
# folder1/image_1571952990.jpg
# folder1/image_1571952539.jpg
# folder1/image_1571953377.jpg
# folder1/image_1571952700.jpg
# folder1/image_1571953370.jpg
# folder1/image_1571953244.jpg
# folder1/image_1571952690.jpg
# folder1/image_1571953433.jpg
# folder1/image_1571953426.jpg
# folder1/image_1571953265.jpg
# folder1/image_1571952633.jpg
# folder1/image_1571952594.jpg
# folder1/image_1571952579.jpg
# folder1/image_1571953363.jpg
# folder1/image_1571952608.jpg
# folder1/image_1571953381.jpg
# folder1/image_1571952983.jpg
# folder1/image_1571952740.jpg
# folder1/image_1571952729.jpg
# folder1/image_1571952532.jpg
# folder1/image_1571953415.jpg
# folder1/image_1571952704.jpg
# folder1/image_1571952726.jpg
# folder1/image_1571952736.jpg
# folder1/image_1571952640.jpg
# folder1/image_1571952543.jpg
# folder1/image_1571952976.jpg
# folder1/image_1571952686.jpg
# folder1/image_1571952643.jpg
# folder1/image_1571952650.jpg
# folder1/image_1571953422.jpg
# folder1/image_1571952743.jpg
# folder1/image_1571953436.jpg
# folder1/image_1571952972.jpg
# folder1/image_1571952629.jpg
# folder1/image_1571953251.jpg
# folder1/image_1571952546.jpg
# folder1/image_1571952597.jpg
# folder1/image_1571953404.jpg
# folder1/image_1571952583.jpg
# folder1/image_1571952757.jpg
# folder1/image_1571952528.jpg
# folder1/image_1571952754.jpg
# folder1/image_1571952576.jpg
# folder1/image_1571952636.jpg
# folder1/image_1571953261.jpg
# folder1/image_1571953254.jpg
# folder1/image_1571952750.jpg
# folder1/image_1571953367.jpg
# folder1/image_1571952521.jpg
# folder1/image_1571952747.jpg
# folder1/image_1571953237.jpg
# folder1/image_1571953384.jpg
# folder1/image_1571952693.jpg
# folder1/image_1571953412.jpg
# folder1/image_1571953360.jpg
# folder1/image_1571952969.jpg
# folder1/image_1571952604.jpg
# folder1/image_1571952683.jpg
# folder1/image_1571952590.jpg
# folder1/image_1571953429.jpg
# folder1/image_1571952601.jpg
# starting upload
# Image batch upload failed.
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OKDuplicate
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# uploaded images
